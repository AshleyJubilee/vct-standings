# %%
import pandas as pd

# %%
regions = {'amer': pd.read_csv('resources/amerTeams.csv'), 
           'cn': pd.read_csv('resources/cnTeams.csv'), 
           'pac': pd.read_csv('resources/pacTeams.csv'), 
           'emea': pd.read_csv('resources/emeaTeams.csv')}

# %%
regions['cn']
# Out:
#     Unnamed: 0                  team  Group  Wins  Losses  Map Wins  \
# 0            0            All Gamers  omega     3       1         6
# 1            1       Bilibili Gaming  alpha     2       3         6
# 2            2  Dragon Ranger Gaming  alpha     3       2         8
# 3            3         EDward Gaming  alpha     3       1         7
# 4            4       FunPlus Phoenix  omega     4       0         8
# 5            5             JD Gaming  omega     0       4         3
# 6            6          Nova Esports  alpha     1       4         4
# 7            7                 TYLOO  omega     1       3         4
# 8            8    Titan Esports Club  omega     2       2         5
# 9            9         Trace Esports  omega     3       1         6
# 10          10        Wolves Esports  alpha     2       3         5
#
#     Map Losses  Map Delta  Round Wins  Round Losses  Round Delta
# 0            4          2         123           111           12
# ...
